# %% [markdown]
# #Los operadores lógicos

# %% [markdown]
# Recordemos los operadores de comparación
#
# ![img1](https://facialix.com/images/cond.png)

# %% [markdown]
# y veamos algunos ejemplos de los operadores logicos en acción
#
# ![img2](https://facialix.com/images/logicos.png)

# %% [markdown]
# **En este ejercicio debes mostrar el valor que se obtiene de las sentencias al ejecutarlas en codigo y explicarlas:**

# %% [markdown]
# 1) **not true**

# %%
#Escribe el codigo aquí
x=5
y=6
x is not y
# Out:
# True

# %% [markdown]
# Escribe el explicacion aquí
#
# La variables x y y tienen valores asignados (x=5 y y =6), ambos diferentes, por tanto "5 no es 6" o "x no es y" y eso es verdadero
# 🖍 ...

# %% [markdown]
# 2) **not (1+2 != 3)**

# %%
#Escribe el codigo aquí
#1+2 != 3
1+2 is not 3
# Out:
# False

# %% [markdown]
# Escribe el explicacion aquí
#
# El operador not nos dice que es falso que 3 no es 3 porque este operador invierte el resultado o en su defecto, esta comparando una operación "1+2" con un numero predefinido

# %% [markdown]
# 3) **x = (len("jugar") > 5) and (len("jugar") < 10)**

# %%
#Escribe el codigo aquí
(len("jugar") > 5) and (len("jugar") < 10)
# Out:
# False

# %% [markdown]
# Escribe el explicacion aquí
#
# dentro de los valores comparados hay uno que no es correcto/verdadero ya sea el >5 o el <10

# %% [markdown]
# 4) **"alto"[2] == "t" and x**

# %%
#Escribe el codigo aquí
"alto"[2] == "t" and x

# %% [markdown]
# Escribe el explicacion aquí
#
# comprobamos que "alto"[2] == "t"  es verdadero, pero al cmpararlo con una tercer variable "and x" rompe el verdadero, por tanto el resultado es falso

# %% [markdown]
# 5) **842913%10 != 3 and len("café") == 3**

# %%
#Escribe el codigo aquí
842913%10 != 3 and len("café") == 3
# Out:
# False

# %% [markdown]
# Escribe el explicacion aquí
#
# aunque en principio la división 842913%10 si es diferente de tres, se comparan tambien valores de caracteres donde se rompe la "igualdad"

# %% [markdown]
# 6) **0!=0 or "a" < "y"**

# %%
#Escribe el codigo aquí
0!=0 or "a" < "y"
# Out:
# True

# %% [markdown]
# Escribe el explicacion aquí
#
# al menos una condición se cumple que es la de "a"<"y"

# %% [markdown]
# 7) **True or int("50") >= 50**

# %%
#Escribe el codigo aquí
True or int("50") >= 50
# Out:
# True

# %% [markdown]
# Escribe el explicacion aquí
#
# al menos una condición se cumple

# %% [markdown]
# 8) **edad = 20**
#
# **not(x) or edad%2==0**

# %%
#Escribe el codigo aquí
edad = 20
not(x) or edad%2==0
# Out:
# True

# %% [markdown]
# Escribe el explicacion aquí
#
# el módulo de edad se si cero por tanto una de las condiciones del or se cumplen y es verdadero

# %% [markdown]
# 9) **es_cliente = False**
#
# **not (es_cliente and not(edad < 18))**

# %%
#Escribe el codigo aquí
es_cliente = False
not (es_cliente and not(edad < 18))
# Out:
# True

# %% [markdown]
# Escribe el explicacion aquí
#
# es un falso invertido por el primer not

# %% [markdown]
# ###Recursos extra para estudiar y ejercios

# %% [markdown]
# - Video corto de Coursera: [Tablas de verdad y álgebra booleana](https://www.coursera.org/lecture/programacion-python/tablas-de-verdad-y-algebra-booleana-JJs0E)
# - Articulo corto de [Tablas de la verdad](https://www.ecured.cu/Tablas_de_la_verdad)
# - Ejercicios practicos en portal de [Tablas de Verdad](https://www.edu.xunta.gal/espazoAbalar/sites/espazoAbalar/files/datos/1493724904/contido/tablas_de_verdad.html)
# - Guía de [Ejercicios de Lógica](https://www.fing.edu.uy/tecnoinf/mvd/cursos/mdl1/material/pra/buceo_noct/mdl1-pr-logica.pdf)
